# %%
#import torch
#from transformers import CLIPProcessor, CLIPModel
#from PIL import Image
from xml.dom import minidom
import os
import pickle
from collections import Counter
from nltk import ngrams
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
import re
import glob
# Out:
# [nltk_data] Downloading package stopwords to /Users/rhia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/rhia/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # CLIP Model on IU Data

# %% [markdown]
# # Map the Findings to Relevant Images

# %%
ctr=0
img_findings_dict={}

for filename in os.listdir('input/ecgen-radiology/'):
    docs=minidom.parse('input/ecgen-radiology/'+filename)
    img_ref=docs.getElementsByTagName("AbstractText")
    
    for i in img_ref:
        if i.getAttribute("Label")=='FINDINGS': 
            if i.firstChild:
                finding=str(i.firstChild.data)
                f_lst=finding.split()
                if 1<len(f_lst)<63:
                    img_ref=docs.getElementsByTagName("parentImage")
                    img_arr=[str(i.getAttribute("id")) for i in img_ref]
                    if finding not in img_findings_dict:
                        img_findings_dict[finding]=img_arr
                    else:
                        for i in img_arr:
                            img_findings_dict[finding].append(i)

# %%
print("There are {} unique findings in the dataset".format(len(img_findings_dict)))
# Out:
# There are 2507 unique findings in the dataset

# %% [markdown]
# # Find the Most 1-Gram used in Findings
#
# Pre-processing:
# - Remove Stop Words as defined by the standard NLTK english language and meaningless words in the dataset like 'within','xxxx','show'
# - Remove punctuation
# - Only consider nouns as flagged by the NLTK package
#
# Future Steps:
# - Consider making plural words singular
#
# The 10 most used nouns in the dataset are: 'chest','stable','heart','cardiomegaly','ribs','clear','hyperexpansion', 'hyperinflation', 'vasculature','lungs.'
#
# We wanted to develop as robust as possible a dataset for the first pass, so we consider the top 500 most common words.

# %%
stop_words=set(stopwords.words('english'))
additional_stop_words=['within','xxxx','show']

for w in additional_stop_words:
    stop_words.add(w)

findings_lst=[f for f in img_findings_dict]

findings_str_lst=[f.split() for f in findings_lst]
findings_tokens=[w for f in findings_str_lst for w in f]

no_stop_wrds_find_lst=[]
for w in findings_tokens:
    if w.lower() not in stop_words: no_stop_wrds_find_lst.append(w)

unique_words_lst=list(set(no_stop_wrds_find_lst))
pos_unique_word_lst=nltk.pos_tag(unique_words_lst)
noun_pos_lst=['NN','NNS','NNP','NNPS']
nouns_list=[w for w,pos in pos_unique_word_lst if pos in noun_pos_lst]

findings_str=" ".join(nouns_list)
rem_punc_str=re.sub(r'[^\w\s]', '', findings_str)

findings_str_lower=rem_punc_str.lower()

# %%
ngram_counts=Counter(ngrams(findings_str_lower.split(),1))
ngram_counts.most_common(500)

noun_500_common_lst=[w[0][0] for w in ngram_counts.most_common(500)]

# %% [markdown]
# # Identify Findings with Common Nouns
#
# 3 Findings with Common Nouns:
#
# 1. heart size normal. lungs are clear. xxxx are normal. no pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.
#
# 2. the heart size and pulmonary vascularity appear within normal limits. lungs are free of focal airspace disease. no pleural effusion or pneumothorax is seen. vp shunt tubing is identified. the bony structures, as visualized, appear unremarkable.
#
# 3. the heart size and pulmonary vascularity appear within normal limits. the lungs are free of focal airspace disease. no pleural effusion or pneumothorax is seen. picc line is in xxxx. the tip is in the upper right atrium.','the heart is normal in size and contour. the lungs are clear, without evidence of infiltrate. there is no pneumothorax or effusion. multiple punctate round xxxx xxxx over the abdomen on the lateral view. these may reside within, or outside of the patient.
#
#
# Recognizing that there are frequent phrases in each finding, we move to parsing the findings at the end of a statement ('.') and then identify the statements with the common nouns.

# %%
def str_with_common_nouns(list_strings,target_wrds_lst):
    """
        Identify strings with most common nouns.
        
        @P: list_strings (list) - list of strings that may contain a common word
            target_wrds_lst (list) - list of target words/common words
            
        @R: str_with_common_wrds_lst (list) - list of strings with common words
    """
    
    strs_lower_lst=[s.lower() for s in list_strings]
    str_with_common_wrds_lst=[]

    for s in strs_lower_lst:
        if any(w in s for w in target_wrds_lst):
            str_with_common_wrds_lst.append(s)
    
    return str_with_common_wrds_lst

# %%
findings_common_nouns_lst=str_with_common_nouns(findings_lst,noun_500_common_lst)

# %% [markdown]
# # Identify Statements with Common Nouns
#
# There are 12,151 statements that contain at least one of the common nouns.
#
# Ex: 'no pneumothorax or pneumomediastinum'
#     ' heart size is upper limit normal'
#
# Recognizing that there are duplicate statements and non-seense information with 'xxxx,' we move to tidying the statements.

# %%
statement_lst=[f.split(".") for f in findings_lst]
statement_lst_flat=[s for f in statement_lst for s in f]
        
statement_common_nouns_lst=str_with_common_nouns(statement_lst_flat,noun_500_common_lst)
print("There are {} non-distinct statements that contains at least 1 of the common nouns".format(len(statement_common_nouns_lst)))
# Out:
# There are 12151 non-distinct statements that contains at least 1 of the common nouns

# %% [markdown]
# # Identify Unique Statements
#
# - Strip white space
# - Remove newline characters and duplicate whitespace
#
# This results in 5,080 unique statements that could be used for further analysis.
#
# Future Steps:
# - Consider cases that are incredibly similar: 'clear lungs' and 'clear right lung'
# - Remove incomplete statements: statements with 'xxxx'

# %%
#complete_statements=[]
#complete_flag=True

statements_lst=[]

for s in statement_common_nouns_lst:
    s=s.strip()
    s=" ".join(s.split())
    rem_punc_str=re.sub(r'[^\w\s]', '', s)
    
    s_str=s.split()
    #for w in s_str: 
        #if re.search("^xx.", w): complete_flag=False
    
    #if complete_flag==True: 
        #complete_statements.append(s)
        
    #complete_flag=True
    
    statements_lst.append(s)
    
#unique_statements_lst=list(set(complete_statements))
unique_statements_lst=list(set(statements_lst))

print("There are {} distinct statements that contains at least 1 of the common nouns".format(len(unique_statements_lst)))
# Out:
# There are 5080 distinct statements that contains at least 1 of the common nouns

# %%
unique_statements_lst
# Out:
# ['prosthetic right humeral head',
#  'the lungs are hyperexpanded the hemidiaphragms are flattened',
#  'no focal alveolar consolidation, no definite pleural effusion seen',
#  'no pneumothorax or significant pulmonary edema',
#  'the heart and cardiomediastinal silhouette or normal in size and contour',
#  'no pleural effusion or pneumothorax',
#  'the left base opacities could represent early pneumonia or areas of atelectasis',
#  'heart size, mediastinal contour, and pulmonary vascularity are similar to comparison exam and within normal limits',
#  'the heart is not grossly enlarged',
#  'dual-xxxx cardiac pacemaker is in stable, xxxx position',
#  'heart and mediastinum are stable with ectasia of the aorta',
#  'hyperexpansion, flattening of diaphragms, and increased ap diameter consistent with history of copd',
#  'osteopenia and degenerative changes are identified',
#  'findings may reflect focal airspace disease or adenopathy',
#  'right knee',
#  'the distribution xxxx pulmonary edema',
#  'the heart is large, the pulmonary xxxx are engorged',
#  'the mediastinum is stable with tortuous aorta',
#  'there degenerative changes of the spine',
#  'mild central vascular congestion',
#  'no acute infiltrate or pleural effusion are appreciated',
#  'there is a loss of lung volume on the left due to postsurgical change',
#  'stable tortuous aorta',
#  'calcified granuloma is present within the right lower lobe',
#  'the cardiac silhouette is enlarged',
#  'frontal (on two cassettes) and lateral views of the chest with overlying external cardiac monitor leads show an unchanged cardiomediastinal silhouette',
#  'the aorta is tortuous and atherosclerotic',
#  'there has been xxxx xxxx sternotomy',
#  'probable mild cardiomegaly',
#  'atherosclerotic calcification within the aorta',
#  'vague opacity in the right midlung',
#  'there are stable anterior wedge xxxx deformities of 2 midthoracic vertebral bodies',
#  'no focal consolidation, pneumothorax, or large pleural effusion identified (blunting of costophrenic recesses bilaterally may represent small effusions or pleural thickening/scar',
#  'heart size mildly enlarged, stable mediastinal and hilar contours, mediastinal calcifications suggest a previous granulomatous process',
#  'degenerative changes in the spine',
#  'central pulmonary vascularity is again accentuated',
#  'heart size within normal limits, stable mediastinal contours',
#  'there are vascular calcifications over the aortic xxxx',
#  'lung volumes are low',
#  'no convincing acute bony findings',
#  'patient is rotated',
#  'stable right upper lobe calcified granuloma',
#  'no focal consolidation, pneumothorax, or effusion',
#  'bony thorax and soft tissue grossly unremarkable',
#  'the bony elements are not remarkable',
#  'cardiomediastinal contour and pulmonary vascularity stable and within normal limits',
#  'xxxx opacities are present in both lung bases',
#  'right lower lobe xxxx calcified granuloma',
#  'nonobstructive bowel xxxx pattern',
#  'no focal thoracic bony findings',
#  'lungs are overall hyperexpanded with flattening of the diaphragms',
#  'there are calcified granulomas within the left lower lobe',
#  'the cardiac mediastinal silhouettes are normal',
#  'postsurgical changes of left hemithorax are stable',
#  'there are streaky left basilar opacities and blunting of the left costophrenic sulcus xxxx secondary to a small effusion',
#  'coarsened interstitial testes appear chronic and compatible with emphysema',
#  'bilateral pleural thickening is noted',
#  'retained xxxx bullet fragments noted within the left upper and lower lobes',
#  'no change right anterior soft tissue surgical clips',
#  'lung volumes are decreased, with crowding',
#  'there is mild prominence of the interstitial markings which are unchanged',
#  'the lungs are hyperexpanded with flattening of hemidiaphragms and increased retrosternal airspace',
#  'heart size within normal limits, no typical findings of pulmonary edema',
#  'lungs are mildly hypoinflated with asymmetric elevation of the right hemidiaphragm, of uncertain chronicity',
#  'defibrillator xxxx is in stable position',
#  'scoliosis is present',
#  'calcified right infrahilar lymph xxxx again seen',
#  'interposition of the colon in the left upper quadrant',
#  'no acute lung infiltrates',
#  'unremarkable bony structure',
#  'the heart silhouette and mediastinal contours are not enlarged',
#  'chest: stable cardiomediastinal silhouette',
#  'xxxx opacities are noted in the lung bases compatible with scarring or atelectasis',
#  'there is patchy retrocardiac opacity',
#  'lungs are hyperinflated',
#  'stable position of cardiac pacemaker and leads',
#  'degenerative changes noted of the thoracic spine',
#  'there is a moderate amount of retained contrast within the distal esophagus',
#  'stable cardiomediastinal silhouette with normal heart size and aortic ectasia/tortuosity, stable mediastinal contours',
#  'there is an s-shaped scoliosis of the thoracic spine',
#  'no focal consolidation, suspicious pulmonary opacity, pneumothorax or definite pleural effusion',
#  'the lungs are clear with no evidence of pleural effusion or pneumothorax',
#  'heart and mediastinum are within normal limits',
#  'atherosclerosis of the aortic xxxx',
#  'evaluation is limited by body habitus and ap technique',
#  'calcification is seen over the anterior mediastinum xxxx a calcified lymph node at is not identified on the pa projection',
#  'mixed nodular interstitial opacities distributed through bilateral lungs, right greater than left',
#  'otherwise lungs are clear',
#  'calcified granuloma in the right lower lobe is stable in appearance xxxx compared to the previous examinations',
#  'volume loss in the left lung, stable',
#  'there is no acute pulmonary consolidation, pleural effusion or pneumothorax',
#  'significantly decreased subcutaneous soft tissue since comparison radiograph',
#  'the lungs are mildly hypoinflated without focal consolidation',
#  'cardiomediastinal size is within normal limits',
#  'cardiomediastinal silhouette is xxxx',
#  'postsurgical changes of esophagectomy and gastric pull-through are stable',
#  'the xxxx and mediastinum appear normal',
#  'xxxx right basal airspace opacity',
#  'lower cervical xxxx arthritis',
#  'mild apical scarring',
#  'nodular densities projecting over the posterior 9th ribs bilaterally are consistent with nipple shadows',
#  'the pulmonary vascular markings are symmetric and normal',
#  'there is mild midthoracic dextroscoliosis, with the xxxx xxxx otherwise grossly intact',
#  'there is a left-sided tunneled catheter, the distal tip at the mid superior xxxx xxxx level',
#  'xxxx opacities in the right lower lung representing atelectasis versus scarring',
#  'the osseous structures are grossly normal',
#  'aorta is ectatic',
#  'there is no suprapatellar effusion',
#  'no large pneumothorax or effusion',
#  'we again note the left hilar calcifications that are unchanged from the prior studies',
#  'chronic-appearing xxxx opacities are unchanged and represent emphysema',
#  'left xxxx-a-xxxx is in xxxx with the tip projecting over the caval atrial junction',
#  'calcified lymph xxxx in both xxxx',
#  'mild degenerative changes are present in the spine',
#  'no pleural effusion is identified on the lateral view',
#  'left base opacities again noted, stable',
#  'stable tortuous thoracic aorta',
#  'the patient was shielded',
#  'there is a moderate sized hiatal hernia',
#  'ap view was obtained due to patient condition',
#  'no pneumothorax or effusion',
#  'the overlying bony structures reveal no acute abnormalities',
#  'there are diffuse increased interstitial markings, suggestive of pulmonary fibrosis in bilateral lung xxxx',
#  'negative for acute displaced rib fracture',
#  'cardiac xxxx generator leads xxxx over the right atrium and right ventricle',
#  'distal clavicle shortening also present on the previous exam, possibly posttraumatic or postsurgical',
#  'prior chest surgery',
#  'well circumscribed 11 mm right upper lobe nodule, unchanged appearance from previous examination 7 years ago',
#  'torturous/ectatic thoracic aorta',
#  'heart size is within normal limits for ap technique',
#  'there are large calcified mediastinal and right hilar granulomas',
#  'blunting of the bilateral costophrenic xxxx',
#  'atherosclerotic calcification of the aorta',
#  'degenerative endplate changes of the thoracic spine with an age-indeterminate, mild wedge xxxx deformity of a midthoracic vertebral body',
#  'callus or granulomas identified',
#  'heart size at the upper limits of normal',
#  'there is a left-sided cardiac pacemaker identified whose leads are stable in position overlying the right atrial appendage and right ventricle',
#  'there has been clearing of the left base airspace disease',
#  'streaky bibasilar opacities, xxxx atelectasis',
#  'decreased biapical vascular markings with moderate hyperexpansion the lungs, consistent with obstructive pulmonary disease',
#  'there is xxxx opacity in the left perihilar upper lobe',
#  'no acute infiltrate is seen',
#  'spinal stimulator is in xxxx with tip overlying the t9 vertebral body',
#  'heart size is as is within normal limits',
#  'heart and pulmonary xxxx are normal',
#  'there is bihilar prominence',
#  'the xxxx are normal',
#  'the patient is status post cabg',
#  'mild spondylosis',
#  'right picc line is in xxxx',
#  'xxxx opacity persists in the right midlung',
#  'xxxx opacities projecting over the right apex and mediastinum on pa view are artifactual',
#  'considering technical factors heart size xxxx within normal limits',
#  'no focal airspace consolidations',
#  'degenerative disease of the thoracic spine is present',
#  'postop changes of cabg with mild cardiomegaly',
#  'there is an retrocardiac density compatible hiatal hernia',
#  'the opacity at the left lung base appears stable from prior exam',
#  'no focal consolidation, large pleural effusion or pneumothorax is identified',
#  'lordotic projection and large body habitus',
#  'there is no pneumothorax or large pleural effusion',
#  'the heart size and pulmonary vascularity appear within normal limits',
#  'the lungs are hyperinflated',
#  'there is xxxx streaky opacification in the right midlung',
#  'heart size is upper limits of normal but stable',
#  'there is ectasia/tortuosity of the thoracic aorta',
#  'in the interval, bibasilar interstitial infiltrates and pulmonary venous engorgement have resolved',
#  'a 5 mm stable right apical nodule',
#  'there is ectasia of the thoracic aorta',
#  'on the lateral view in the anterior costophrenic xxxx, there is a 2',
#  'considering differences in technical factors xxxx stable cardiomediastinal silhouette with normal heart size',
#  'hiatal hernia',
#  'heart size and mediastinal contours are normal',
#  'heart size near top normal, bilateral hilar fullness nonspecific in appearance, mild aortic ectasia/tortuosity',
#  'calcified left hilar lymph node',
#  'there is no pneumothorax or pleural effusion',
#  'left-sided pacemaker xxxx and associated xxxx are unchanged in position',
#  'rotated with low lung volumes',
#  'cardiomediastinal silhouette is within normal limits of size in appearance',
#  'lungs are clear bilaterally otherwise',
#  'heart and mediastinum are unremarkable',
#  'left costophrenic opacity may represent pleural or pericardial fat',
#  'there is a large calcified granuloma in the right apex',
#  'a few bandlike opacities are present on the lateral view which appear to represent small areas of scarring',
#  'mild emphysema',
#  'there are 3 cardiac pacing leads in stable position',
#  'the cardiac silhouette, mediastinum, and pulmonary vasculature are within normal limits',
#  'question left basilar atelectasis versus infiltrate',
#  'there is a right chest xxxx with central venous catheter tip overlying the high svc',
#  'the right heart xxxx appears obscured and there are streaky right medial basilar airspace opacities, possibly due to airspace disease or atelectasis',
#  'there is a small to moderate sized right apical pneumothorax which measures approximately 2',
#  'there is xxxx deformity of the t9 vertebral body',
#  'nipple ring on left',
#  'heart size is unchanged',
#  'no effusions, consolidation or pneumothorax',
#  'calcified granuloma is present in the left base',
#  'there is lucency involving the lateral aspect of the left clavicle',
#  'lungs otherwise are clear',
#  'there is xxxx patchy opacification in the right upper and left lower lobes',
#  'no focal air space opacities or pleural effusion',
#  'otherwise, visualized osseous structures are unremarkable',
#  'mild dextroscoliosis of the spine',
#  'no focal infiltrate, pneumothorax or pleural effusion identified',
#  'a small right pleural effusion the present',
#  'soft tissues are unremarkable',
#  'this xxxx represents a calcified granuloma',
#  'stable mild background chronic interstitial changes',
#  'intact xxxx xxxx',
#  'stable mild interstitial opacities',
#  'normal pulmonary vasculature and central airways',
#  'the osseous structures are intact',
#  'normal heart size and mediastinal contour appear normal pulmonary vascularity',
#  'numerous bilateral pulmonary nodules have increased in size and number xxxx compared to prior study',
#  'limbus vertebra noted within the partial visualized lumbar vertebral body',
#  'no focal consolidation, effusion, or pneumothorax',
#  'there is some minimal patchy opacity in left base which may represent atelectasis or scarring',
#  'accentuated thoracic kyphosis',
#  'the cardiomediastinal silhouette is normal size and configuration',
#  'a calcific density in the left midlung zone xxxx represents old granulomatous disease',
#  'resolved interstitial edema',
#  'lung parenchyma is clear, no focal airspace consolidation',
#  'lungs are mildly hypoinflated but grossly clear of focal airspace disease, pneumothorax, or pleural effusion',
#  'stable cardiomegaly and mediastinal contour',
#  'arthritic changes are seen',
#  'calcified left coronary arteries noted',
#  'calcified breast implants obscure some detail',
#  'the heart and cardiomediastinal silhouette are normal in size and contour',
#  'the heart is normal',
#  'frontal view kyphotic and rotated, low lung volumes with bronchovascular crowding',
#  'stent visualized in the right upper quadrant, xxxx biliary stent',
#  'there are xxxx opacities which appear to xxxx xxxx above the right xxxx fissure',
#  'interval increased bilateral interstitial opacities, with probable left lower lobe infiltrate',
#  'no large effusion or visualized pneumothorax',
#  'right lung is grossly clear',
#  'stable positioning of the dual-xxxx cardiac xxxx device',
#  'there is a left basilar airspace opacity',
#  'there is mild atelectatic change draped over the hernia sac',
#  'the lungs are normally inflated and clear',
#  'stable scarring near the right lung apex along the lateral aspect',
#  'streaky bibasilar opacities, as well',
#  'cardiomediastinal silhouette is within normal limits of size and appearance',
#  'scattered degenerative changes of the thoracic spine',
#  'there is eventration of right hemidiaphragm',
#  'the thoracic aorta is unfolded and tortuous',
#  'there is minimal pulmonary vascular congestion',
#  'lung volumes are low with asymmetric elevation of the right hemidiaphragm',
#  'prominent epicardial fat',
#  'mild spine curvature noted',
#  'negative for pneumothorax, pleural effusion or large focal airspace consolidation',
#  'dense nodule in the right lower lobe suggests a previous granulomatous process',
#  'left-sided dual-xxxx cardiac xxxx in stable position',
#  'the lungs are mildly hyperlucent but clear',
#  'degenerative changes of the bilateral xxxx',
#  'minimal osteophytes of the thoracic spine',
#  'no infiltrates in the lungs',
#  'there is no effusion or pneumothorax',
#  'there is again right-sided superior hilar retraction and mild rightward xxxx deviation',
#  'negative for pneumothorax or large pleural effusion',
#  'not visualized on lateral exam',
#  'there is tortuosity of the thoracic aorta, stable',
#  'the pulmonary vasculature is normal in appearance',
#  'biapical pleuroparenchymal irregularities most compatible with scarring, chronic appearing right 5th rib contour deformity',
#  'no pneumothorax pleural effusion or focal consolidation',
#  'correlate clinically with history of fracture',
#  'no acute osseous lesions are identified',
#  'lungs are otherwise clear bilaterally',
#  'persistent mild elevation right hemidiaphragm',
#  'cardiomediastinal silhouette is stable and unremarkable',
#  'heart size, mediastinal contour, and pulmonary vascularity are within normal limits',
#  'the scarring in the left lower lobe is again noted and unchanged from prior exam',
#  'postsurgical changes of anterior lower cervical spine fusion',
#  'radiopaque contrast from recent esophagram projects over the left upper abdomen',
#  'xxxx sternotomy xxxx and mediastinal postsurgical changes',
#  'bridging syndesmophytes are noted throughout visualized thoracolumbar spine',
#  'no focal airspace consolidation, pneumothorax, pleural effusion, or pulmonary edema',
#  'there is no focal consolidation or pneumothorax',
#  'there is mild streakiness in the right base',
#  'stable left chest cardiac xxxx generator with 2 distal leads in right atrium and right ventricle',
#  'there are postsurgical changes of the left hemithorax with mild left-sided volume loss as evidenced by diaphragm elevation',
#  'moderate sized right loculated pleural effusion with right lower lobe atelectasis',
#  'moderate degenerative changes of the thoracic spine',
#  'increased xxxx opacities on lateral projection xxxx reflect bronchovascular crowding',
#  'right perihilar opacities',
#  'there is a xxxx airspace opacity in the left upper lung',
#  'right pleural effusion is slightly increased in size',
#  'calcified right hilar granulomas',
#  'bibasilar atelectasis/infiltrate',
#  'visualized osseous structures intact',
#  'normal heart size and hilar vascular markings',
#  'normal pulmonary vasculature',
#  'stable right paratracheal prominence, consistent with known calcified lymph node, seen on prior ct chest dated xxxx',
#  'left basilar retrocardiac opacity',
#  'scattered degenerative changes throughout the thoracic spine',
#  'stable cholecystectomy clips in the right upper quadrant',
#  'the lungs are hyperinflated but clear',
#  '5 cm nodular opacity projecting over left hilum',
#  'the thoracic aorta is mildly tortuous',
#  'small amount of subdiaphragmatic free air',
#  'stable mild thoracic levoscoliosis',
#  'the cardiomediastinal silhouette is normal and unchanged compared to prior examination',
#  'mildly hyperinflated lungs with flattened posterior diaphragm',
#  'patient is status post cabg',
#  'there is a left upper lung granuloma',
#  'scattered granulomas and bilateral perihilar calcified lymph xxxx',
#  'lungs are xxxx',
#  'bibasilar atelectasis and small left-sided pleural effusion',
#  'xxxx scarring left base',
#  'heart size is moderately enlarged',
#  'a minimally displaced fracture is present on right rib 4',
#  'bibasilar air space opacities have significantly improved',
#  'surgical clips are present in the left axilla',
#  'a right central line has its tip at the superior xxxx xxxx',
#  'right 7th and 8th rib deformities are noted',
#  'there are small calcified nodules in the superior segment of the right lower lobe, xxxx old granulomatous infection',
#  'no effusion or pneumothorax',
#  'pa and lateral views were obtained',
#  'the xxxx examination consists of frontal and lateral radiographs of the chest',
#  'there is a large hiatal hernia',
#  'there is again hilar enlargement, xxxx superimposes enlarged pulmonary vasculature',
#  'however as compared to the prior study, there are increased perihilar opacities bilaterally',
#  'there has been clearing of left base airspace opacities',
#  'the cardiomediastinal silhouette is normal in size',
#  'there is no focal consolidation, pneumothorax or effusion',
#  'the cardiac xxxx generator overlies left upper thorax with xxxx xxxx tips overlying the right atrium and ventricles',
#  'the lung xxxx are free of infiltrate and there is no pleural effusion',
#  'there is a kyphosis and osteopenia of the thoracic spine',
#  'lung volumes are low, but no focal infiltrates are present',
#  'the heart, xxxx, and mediastinum are normal',
#  'heart size is normal lungs are clear',
#  'aorta is calcified ectatic and tortuous',
#  'the cardiac silhouette is at the upper limits of normal for size',
#  'calcified granuloma right upper lobe',
#  'left basilar airspace opacities',
#  'mediastinal contour and pulmonary vascularity are within normal limits',
#  'airspace opacity in posterior segment on the lateral view',
#  'the lungs are hyperinflated with biapical pleural-parenchymal scarring and upward retraction of the xxxx, similar to the prior study',
#  'there are no focal air space consolidations',
#  'thoracic spine demonstrates mild degenerative changes with some mild xxxx loss of t4 and t7 vertebral bodies',
#  'xxxx xxxx opacities are related to overlying soft tissues',
#  'there is subphrenic intraperitoneal extraluminal xxxx free xxxx',
#  'xxxx are unchanged from previous exam and appear normal',
#  'stable tubing overlying the midabdomen',
#  'there has been interval development of bibasilar opacities',
#  'these are seen diffusely throughout both lungs',
#  'stable xxxx densities in the left base compatible with scarring or chronic subsegmental atelectasis',
#  'previous lower spine cervical fusion',
#  'there is hyperinflation lungs due to small calcification is seen posteriorly in the right which may be pleural',
#  'no focal consolidations or effusions',
#  'degenerative changes of the xxxx',
#  'no pneumothorax or focal airspace disease',
#  'there is focal opacity in the right upper lobe which suggests scar and/or granulomatous calcification',
#  'rounded 1',
#  'mid sternotomy xxxx again noted',
#  'there is mild prominence of the superior mediastinum which is somewhat lucent and xxxx reflects mediastinal and vascular structures',
#  'no focal air space disease',
#  'stable postoperative changes with midline sternotomy xxxx and myocardial revascularization',
#  'xxxx deviation towards the left',
#  'cholecystectomy clips are present',
#  'the cardiomediastinal contours are within normal limits allowing for low lung volumes and patient rotation',
#  'degenerative changes are noted in the spine',
#  'lungs are clear bilaterally, with no focal consolidation, pleural effusion, or pneumothoraces',
#  'no xxxx focal consolidation or pneumothorax',
#  'no xxxx focal infiltrates',
#  'dual-lumen right ij catheter is identified without pneumothorax',
#  'correlate clinically',
#  'in the left lung base, there is a 9 mm nodule that not definitively calcified',
#  'no pneumothorax or pleural effusion',
#  'the lungs are clear without infiltrate',
#  'the lungs are well-aerated',
#  'there is minimal right basilar atelectasis',
#  'increased interstitial markings in the central lungs and bases, right greater than left',
#  'the cardiac silhouette remains moderately enlarged, exaggerated by epicardial fat pads',
#  'no focal airspace disease, pleural effusion, or pneumothorax',
#  'stable normal cardiac size and contour, unremarkable mediastinal silhouette',
#  'no visible pleural fluid',
#  'no overt pulmonary edema',
#  'there is a right chest xxxx with tip projecting over the lower svc',
#  'cardiac silhouette is upper limits of normal in size',
#  'degenerative changes of the spine and the acromioclavicular joints',
#  'hyperexpansion of the lungs with flattening of the diaphragm',
#  'unfolding of the thoracic aorta',
#  'bilateral apical bullae and parenchymal scars are unchanged',
#  'stable calcification of the thoracic aorta',
#  'both costophrenic xxxx are blunted',
#  'there is right upper lobe airspace disease',
#  'calcified ap xxxx lymph xxxx are seen',
#  'apical lordotic frontal view',
#  'there is a right upper lobe nodule measuring 8 mm in diameter',
#  'no focal consolidations, pneumothorax, or effusions identified',
#  'there is no evidence of pneumothorax or large pleural effusion',
#  'the lungs are well-inflated and clear',
#  'no acute, displaced rib fractures',
#  'there is patchy infiltrate within normal right lower lobe',
#  'it is not well visualized on lateral view',
#  'heart size and pulmonary vascular engorgement appear within limits of normal',
#  'reduced lung volumes with basilar atelectasis',
#  'note xxxx of placement of a retention xxxx in the lower cervical spine',
#  'no displaced rib fracture visualized',
#  'there is a posterior basilar xxxx opacity seen on lateral xxxx xxxx representing subsegmental atelectasis, xxxx visualized on lateral view',
#  'lungs are clear without focal air space disease',
#  'calcified granuloma is present in the right lower lobe',
#  'there are calcified left hilar and mediastinal lymph xxxx',
#  'no acute bone findings',
#  'the heart and mediastinum are normal',
#  'diminutive right hilar silhouette, compatible with absence of right xxxx pulmonary artery, as noted on prior ct',
#  'scattered granulomatous changes',
#  'central vascular markings are mildly prominent',
#  'no focal airspace disease',
#  'there is minimal patchy right lower lobe airspace disease identified',
#  'the cardiopulmonary silhouette is normal',
#  'heart size and mediastinal contours are unremarkable',
#  'diffuse bilateral coarse interstitial markings are unchanged',
#  'there is a cardiac xxxx generator identified with 1-xxxx projected over the right ventricle',
#  'old right-sided rib fracture is noted',
#  'the thoracic spine appears intact',
#  'it is not calcified',
#  '[pulmonary vascularity is within normal limits>]',
#  'stable nodular opacity within the left midlung',
#  'scoliosis and arthritic changes of the spine are present',
#  'mild bilateral posterior sulcus blunting, interstitial and alveolar opacities greatest in the central lungs and bases with indistinct vascular margination',
#  'xxxx basilar atelectasis',
#  'osteophytic degeneration kyphotic thoracic spine',
#  "there is prominence of the superior mediastinum which may be partially due to patient's known thyroid mass",
#  'low lung volumes with no significant airspace consolidation',
#  'there is xxxx opacities noted in the right lower lobe, xxxx subsegmental atelectasis',
#  'there are no xxxx of pleural effusion',
#  'there is evidence of prior granulomatous disease',
#  'mediastinum is normal',
#  'the xxxx are intact',
#  'right subclavian catheter tip is in the lower svc',
#  'partially visualized lower cervical spine fusion xxxx',
#  'clips in the right upper quadrant consistent with cholecystectomy',
#  'negative for pneumothorax, pleural effusion, or pneumoperitoneum',
#  'there are endplate changes within the spine',
#  '7 cm',
#  'prominent interstitium is stable',
#  'surgical clips overlying the right breast',
#  'the mediastinal contours are normal',
#  'the right cardiac margin is partially obscured and may be secondary to overlying cardiophrenic fat',
#  'chronic increased interstitial markings without evidence of focal infiltrate',
#  '4 cm projecting retrosternally on lateral view only',
#  'bilateral costophrenic xxxx blunting is present',
#  'no focal consolidation, pneumothorax or large pleural effusion',
#  'atherosclerotic calcifications are present in the aortic xxxx',
#  'heart size and vascularity are normal',
#  'there is a calcified granuloma in the left upper lobe',
#  'there is a stable granuloma overlying a lower thoracic vertebral body',
#  'no focal airspace consolidation or effusion',
#  'there is slight elevation of left hemidiaphragm with xxxx left basilar subsegmental atelectasis',
#  'the lungs are otherwise clear without focal infiltrates',
#  'the heart is large',
#  'prominent increased interstitial markings in both lungs are unchanged in the interval',
#  'postsurgical changes noted overlying the left axilla',
#  'there has been interval placement of a left chest xxxx, with its distal tip in the left sided svc',
#  'heart and mediastinum are stable given the lung volumes',
#  'increased retrosternal airspace',
#  'stable appearance of scarring at lung bases',
#  'slightly unfolded ascending and descending aorta',
#  'diffuse bilateral reticulonodular interstitial opacities',
#  'redemonstrated syndesmophyte',
#  'the visualized bony structures reveal no abnormalities',
#  'there is a small right lower lobe calcified granuloma that is unchanged from prior examinations',
#  'the mediastinal and hilar lymph xxxx are less prominent than previously',
#  'no overt edema',
#  'there has been previous surgical resection of the left 6th rib',
#  'the negative for pneumothorax, focal infiltrate, or large pleural effusion',
#  'the lungs are hypoinflated but clear',
#  'there are no infiltrates, effusions, or pneumothorax',
#  'right paratracheal prominence xxxx represents tortuous xxxx',
#  'there is prominence of the interstitial markings with fluid in the fissures consistent with interstitial edema',
#  'calcified thoracic aorta',
#  'there is no focal consolidation, pleural effusion or pneumothorax',
#  'cardiomediastinal silhouette is normal in size and contour',
#  'there has been interval cabg',
#  'vague nodular density right upper lobe overlying the right anterior 2nd and posterior 6th ribs',
#  'thoracic aortic atherosclerotic calcifications',
#  'lateral view reveals mild degenerative changes of the thoracic spine',
#  'cardiomediastinal contour is normal without mediastinal widening',
#  'there is also a 7 mm calcified nodule near the left hilum',
#  'prominent vascular pedicle/upper mediastinal contour',
#  'cardiomediastinal size and contour is grossly normal for ap technique',
#  'there is a prominent epicardial fat xxxx',
#  'stable cardiomediastinal silhouette with normal heart size, mediastinal calcifications suggest a previous granulomatous process',
#  'soft tissue xxxx previously noted along the right lateral chest wall has resolved',
#  'heart is slightly large',
#  'however, in the left lower lobe there is a 1 cm diameter nodule that is not calcified',
#  'the heart size and mediastinal contours appear within normal limits',
#  'right suprahilar calcified lymph xxxx',
#  'hindfoot, midfoot, forefoot xxxx are intact with no fractures or bone destruction',
#  'no focal air space opacities, pleural effusion or pneumothorax',
#  'cardio mediastinal silhouette unremarkable',
#  'there are xxxx streaky opacities predominantly in the left lung base possibly related to scarring and atelectasis',
#  'there residual to prior granulomatous infection',
#  'there is no pleural effusion or pneumothorax',
#  'minimal streaky bibasilar opacities',
#  'stable xxxx sternotomy xxxx',
#  'there is minimal xxxx opacity in the left lung base, xxxx representing atelectasis',
#  'there is no focal opacities',
#  'no suspicious pulmonary nodules or masses',
#  'heart size and mediastinal contour appear within normal limits',
#  'mild aortic ectasia/tortuosity, no typical mediastinal widening to suggest vascular injury',
#  'bony thorax grossly unremarkable',
#  'heart size within normal limits, the typical findings of pulmonary edema',
#  'there is stable elevation of the right hemidiaphragm with questionable increased right basilar airspace opacities',
#  'there is no focal airspace disease',
#  'radiopaque foreign body overlying left chest',
#  '8 cm x 6',
#  'otherwise, the lungs are clear with granulomas and xxxx sulci',
#  'lung volumes are slightly low',
#  'there is a dual-lumen right internal jugular central venous catheter, the distal tip projects over the right atrium',
#  'stable calcified hilar xxxx and granulomas',
#  'there is a region of left upper lobe perihilar opacity identified',
#  'cholecystectomy clips',
#  'there is patchy right base airspace disease',
#  'mediastinal contours unremarkable',
#  'mild prominence of the mediastinum',
#  'pulmonary arteries are prominent centrally',
#  'xxxx amount of focal atelectasis posterior to the left heart',
#  'minimal degenerative changes of the thoracic spine',
#  'no upper lobe airspace disease or cavitary lesions identified',
#  'this was incompletely demonstrated on the ct of the abdomen and pelvis',
#  'the mediastinum and pulmonary xxxx are normal',
#  'specifically, no evidence of rib fractures',
#  'sequela of prior granulomatous disease lung volumes are low with central bronchovascular crowding and patchy basilar atelectasis',
#  'the cardiomediastinal silhouette is within normal limits',
#  'cardiomediastinal contour and pulmonary vascularity within normal limits',
#  'again identified are numerous calcified mediastinal lymph xxxx as well as large calcifications within the left upper and left lower lobes',
#  'no xxxx focal infiltrate is identified',
#  'the lungs are grossly clear',
#  'the bony structures show no acute abnormalities',
#  'there is distortion of the right hilum which may be postsurgical versus neoplastic',
#  'the mediastinum is stable',
#  'bony structures are intact',
#  'no other infiltrates or masses in the lungs',
#  'hyperexpanded lungs without focal consolidation, pneumothorax or large pleural effusion',
#  'the pulmonary vasculature appears normal',
#  'there is mild blunting of both posterior costophrenic sulci, which may reflect xxxx effusions',
#  'heart size within normal limits, stable mediastinal and hilar contours, right chest xxxx tip in the low svc',
#  'there are small bilateral pleural effusions, left greater than right with left basilar opacities',
#  'the heart size and cardiomediastinal silhouette are normal',
#  'the lungs are clear without acute infiltrate, effusion or pneumothorax',
#  'mild patchy bilateral airspace disease',
#  'sternotomy xxxx mediastinal clips noted',
#  'heart silhouette is not enlarged',
#  'aorta is tortuous and atherosclerotic',
#  'stable appearing right perihilar calcified granulomas',
#  'low lung volumes bilaterally with bibasilar airspace opacities, right greater than left',
#  'the distal tip of a right ij dual-lumen central venous catheter is at the xxxx which junction',
#  'mild hyperinflation is noted',
#  'pulmonary vascularity is mildly accentuated',
#  'the heart size is persistently enlarged',
#  'no displaced rib fractures are seen',
#  'lung xxxx are hyperexpanded',
#  'however, there is xxxx loss of vertebral body xxxx at t9 compared xxxx thorax from xxxx',
#  'the descending thoracic aorta is mildly tortuous',
#  'the cardio the cardiac silhouette is of the xxxx of normal',
#  'heart size is now normal',
#  'no definite pleural effusion seen, left bronchovascular crowding without typical findings of pulmonary edema',
#  'there is significant interval decrease in right middle and right lower lobe opacification',
#  'postoperative changes seen in the left humerus',
#  'there is a rounded dense opacity in the lateral left midlung zone probably the left upper lobe most suggestive of a rounded pneumonia',
#  'mild dextro curvature of the thoracic spine, possibly positional',
#  'no large pneumothorax has developed in the interim',
#  'irregular 1',
#  'calcified right upper lobe nodule with a granuloma is again seen but unchanged',
#  'the postoperative cardiomediastinal silhouette is stable and upper limits of normal in size',
#  'mild levoscoliosis of the thoracolumbar spine',
#  'there are extensive fibrotic changes in the right lung with rightward shift of the trachea, similar to the previous exam',
#  'xxxx deformity is noted at the upper thoracic vertebral body',
#  'xxxx scarring and emphysematous changes noted',
#  'the bony structures are normal',
#  'cardiomediastinal silhouette stable and unremarkable',
#  '6 mm nodular opacity overlies the left anterior 5th rib on the frontal view',
#  'prominent mitral annular calcification demonstrated on the lateral view',
#  'the cardiac silhouette size is at the upper limits of normal',
#  'there are mildly low lung volumes without focal consolidation, pneumothorax, or effusion identified',
#  'there is a 6 mm nodular opacity in the right midlung',
#  'xxxx foreign body in the posterior soft tissues appear stable',
#  'no definite focal airspace consolidation or pleural effusion',
#  'worsening central vascular congestion interstitial edema',
#  'prominent substernal air space',
#  'a right internal jugular xxxx this catheter has been exchanged for a large xxxx left internal jugular central venous catheter with the tip at the cavoatrial junction',
#  'the heart is enlarged, stable compared to the previous exam',
#  'remainder of the cardiomediastinal silhouette is normal',
#  'there is no focal air space opacity, pneumothorax, or effusion',
#  'there is a left lung calcified granuloma noted',
#  'there is an marked interval increase in heart size',
#  'is minimal blunting of the pleural spaces, xxxx xxxx effusions',
#  'mild elevation right diaphragm',
#  'degenerative changes of the midthoracic spine are noted',
#  'stable calcified small granuloma in left base',
#  'no focal airspace disease is identified',
#  'there no focal airspace opacities to suggest pneumonia',
#  'cardiomegaly is noted and is stable compared to prior examination from xxxx',
#  'broken of the 4xxxx xxxx xxxx, similar to the prior study',
#  'there multilevel degenerative spine changes',
#  'heart size is upper limit of normal',
#  'no xxxx consolidations',
#  'there is no pneumothorax or pneumomediastinum',
#  'no abnormal airspace consolidation',
#  'no suspicious pulmonary mass or nodule is seen',
#  'calcified right upper lobe pulmonary granuloma and calcified right hilar lymph xxxx',
#  'there are scattered calcified granulomas throughout both lungs',
#  'costophrenic xxxx clear',
#  'there is xxxx dense consolidation within the retrocardiac left lower lobe',
#  'additionally there is a more inferior left upper lobe opacity measuring approximately 6 mm in diameter',
#  'there your regular interstitial changes and possibly fibrosis in the left mid and lower lung zone and region of the right middle lobe',
#  'the cardiomediastinal silhouette and vasculature are within normal limits for size and contour',
#  'scoliosis is present in the thoracic and thoracolumbar spine',
#  'the visualized osseous structures demonstrate mild multilevel degenerative disc disease of the thoracolumbar spine, without acute osseous abnormality',
#  'upper limits of normal heart size',
#  'heart size appears enlarged',
#  'no discrete xxxx projectile visualized',
#  'negative for retrosternal density',
#  'there is stable xxxx scarring or atelectasis in the left midlung',
#  'degenerative changes of thoracic spine',
#  'three images submitted',
#  'the lungs are hyperexpanded with flattened diaphragms',
#  'grossly unchanged appearance of calcified hilar lymph xxxx and scattered calcified granulomas',
#  'interval removal of left-sided chest tube',
#  'no bony abnormality',
#  'there are streaky opacities in the lung bases unchanged, xxxx chronic atelectasis',
#  'hyperinflated lungs with chronic appearing interstitial markings, compatible with emphysema',
#  'lungs are mildly hypoinflated',
#  'mild scarring at the right apex',
#  'visualized xxxx of the chest are within normal limits',
#  'there is mild eventration of right hemidiaphragm',
#  'visualized osseous structures unremarkable',
#  'xxxx right lower lung opacity xxxx represents combination of soft tissue overlay and minimal atelectasis',
#  'calcified granuloma is present in the right base',
#  'exam limited by patient rotation',
#  'calcified aortic xxxx',
#  'opacity within the right middle and lower lobes',
#  'peribronchial cuffing also noted',
#  'heart size and pulmonary xxxx are normal',
#  'there is stable mild cardiomegaly without significant pulmonary vascular congestion',
#  'unfolded calcified aorta',
#  'sequelae of old granulomatous disease is again noted',
#  '3 cm in the right apex',
#  'cardiomediastinal silhouette demonstrates mild tortuosity of the thoracic aorta and atherosclerotic calcifications of the aortic xxxx',
#  'lungs appear clear',
#  'small nodular opacity left upper lobe may represent early infiltrate',
#  'the parenchymal scar in the left lower lobe is unchanged in the interval',
#  'visualized bony structures are intact',
#  'prominent right epicardial fat xxxx',
#  'no focal infiltrates or masses in the lungs',
#  'pulmonary xxxx normal',
#  'there are no bony abnormalities',
#  'no masses or suspicious nodules',
#  'stable, mild dextro curvature of the spine',
#  'negative for pneumothorax or pleural effusion',
#  'mild thoracic spine degenerative changes',
#  'no visualized consolidation',
#  'no focal airspace consolidation, pleural effusion, or pneumothorax',
#  'there is no xxxx focal airspace disease, pneumothorax, or pleural effusion',
#  'central pulmonary vasculature is not engorged',
#  'mild degenerate change of the thoracic spine',
#  'stable normal cardiac size and contour, normal mediastinal silhouette',
#  'no discrete nodules are identified',
#  'stable appearance of the cardiomediastinal silhouette',
#  'cardiac valve replacement',
#  'heart size within normal limits',
#  'no acute displaced clavicle or rib fractures',
#  'without focal consolidation, pneumothorax or pleural effusion',
#  'the tip appears to be in the proximal svc',
#  'right mid lung nodule stable xxxx; etiology not determined',
#  'stable postsurgical changes of the lower cervical spine',
#  'abnormal convexity within the mediastinum xxxx represents adenopathy which is better demonstrated on the prior xxxx',
#  'lungs are xxxx without focal airspace disease',
#  'left hemidiaphragm is slightly elevated, possibly from splinting',
#  'stable left xxxx',
#  'small, nodular opacity in the right upper lobe',
#  'pleural effusions or pneumothorax',
#  'right chest central venous line is noted with tip in the mid svc',
#  'pulmonary vasculature is persistently enlarged',
#  'there are finding status post sternotomy and cabg',
#  'xxxx scar in the right lateral midlung',
#  'negative for focal pulmonary consolidation, pleural effusion, pneumothorax',
#  'surgical clips are seen within the right upper abdomen',
#  'no focal airspace consolidation or pleural effusion',
#  'the cardiac silhouette is not definitively identified and not fully evaluated',
#  'persistent prominent interstitial markings of the right upper lobe',
#  'radiodensity overlying the middle cardiac silhouette, xxxx representing a hiatal hernia',
#  'no focal air space consolidation, pneumothorax, pleural effusion, or pulmonary edema',
#  'the left subclavian icd is again identified',
#  'there is a xxxx 7 xxxx nodular density at the left lung base',
#  'increasing density in the superior segment of the left lower lobe, xxxx seen on lateral view',
#  'no focal alveolar consolidation',
#  'the visualized bony structures reveal no acute abnormalities',
#  'right unilateral nipple ring',
#  'there is mild hyperinflation',
#  'vp shunt tubing is identified',
#  'no consolidation, pneumothorax or large pleural effusion',
#  'healed left rib fractures again noted',
#  'mild hyperinflation of the lungs',
#  'bibasilar airspace opacities, right greater than left',
#  'calcified nodules consistent with chronic granulomatous disease',
#  'calcified left perihilar granuloma redemonstrated',
#  'mild degenerative changes of the thoracic spine',
#  'patchy interstitial infiltrates are also present in the right lower lobe',
#  'borderline heart size',
#  'grossly, the lungs are clear and expanded',
#  "they're stable tortuosity of the aorta",
#  'prominent contour of the ascending aorta, consistent with ectasia',
#  'the largest is noted in the left lower lobe, posteriorly measuring approximately 7',
#  'nodular density projected over the left base with no lateral view correlate xxxx secondary to soft tissue overlay',
#  'normal cardiac size',
#  'lungs are hyperexpanded with flattened diaphragms',
#  'no visualized pneumothorax or large pleural effusion',
#  'xxxx sternotomy xxxx noted',
#  'left ij catheter tip at cavoatrial junction',
#  'xxxx are normal',
#  'no focal airspace consolidation, pleural effusions or pneumothorax',
#  'normal heart size and pulmonary vascularity',
#  'right lung remains clear',
#  'the lungs are otherwise clear without infiltrate',
#  'a large calcified right mediastinal adenopathy, xxxx chronic fungal',
#  'consolidation and some atelectasis are present in the left lower lobe',
#  'limited evaluation of the xxxx xxxx to be grossly intact',
#  'in the left midlung zone, there has been development of a small lung nodule',
#  'there is mild tortuosity to the descending thoracic aorta',
#  'there are surgical clips in the left mediastinum',
#  'stable xxxx deformity of a midthoracic vertebra',
#  'there are no cavitary lesions seen',
#  'thoracic aorta is tortuous',
#  'the bilateral costophrenic xxxx are excluded from the image on the pa view',
#  'mild patchy right upper lobe opacities, similar to slightly improved from xxxx',
#  'surgical xxxx overlie the soft tissues of the neck',
#  'heart size is at the upper limits of normal',
#  'emphysematous changes are identified',
#  'soft tissues and showed unremarkable',
#  'cardiomegaly and/or pericardial effusion',
#  'interval removal of cardiac xxxx generator',
#  'no focal air space consolidation, pneumothorax, or pleural effusion',
#  'unchanged blunting of the right lateral costophrenic xxxx, scarring versus xxxx effusion',
#  'the heart is within normal limits in size',
#  'calcified right lower lobe granuloma',
#  'no pulmonary edema',
#  'no pneumothorax or pleural effusions',
#  'lung lines remain low',
#  'bilateral granulomas are seen scattered throughout the lungs',
#  'there is redemonstration of an aicd with the left chest wall with stable intact xxxx placement',
#  'the heart size is upper limits of normal',
#  'no change in the right middle lobe opacification',
#  'surgical clips are identified in the mediastinum',
#  'the left hilar contour is prominent',
#  'there is xxxx deformity of t12 and l1, unchanged xxxx abdomen xxxx, xxxx',
#  'otherwise, lungs are clear',
#  'surgical xxxx is noted in the right upper quadrant',
#  "right upper lobe airspace disease consistent with pneumonia given patient's history",
#  'the lungs are clear of focal infiltrate',
#  'mild degenerative change is seen within the midthoracic spine',
#  'there is prominence of the central pulmonary vasculature',
#  'surgical cervical xxxx is redemonstrated',
#  'left retrocardiac airspace disease with blunted posterior costophrenic xxxx on lateral view suggesting small pleural effusion',
#  'the heart pulmonary xxxx appear normal',
#  'the heart is is at the upper limits of normal in size',
#  'lungs remain hyperexpanded',
#  'there is relative elevation of the right hemidiaphragm consistent with history of right lower lobectomy, without focal consolidation, pneumothorax, or effusion identified',
#  'the lungs hyperexpanded suggesting emphysema',
#  'there is right basilar air space opacity',
#  'implantable defibrillator is noted',
#  'no acute osseous abnormalities identified',
#  'there is no pleural effusion or the heart is normal',
#  'there is an the right base xxxx/fluid level',
#  'degenerative changes of both xxxx joints',
#  'hyperexpanded lungs with flattened hemidiaphragms, consistent with emphysema',
#  'postsurgical changes are noted in the mediastinum',
#  'surgical clips are present in the right upper quadrant',
#  'mild xxxx left upper lobe atelectasis or scarring',
#  'heart and xxxx remain normal',
#  'stable degenerative changes of the spine',
#  'no focal pulmonary opacity, pleural effusion or pneumothorax',
#  'there is thoracic kyphosis',
#  'the lungs are clear, and without focal air space opacity',
#  'the cardiomediastinal silhouette is within normal limits for size and contour',
#  'the outside x-xxxx is normal except for slight cardiomegaly',
#  'bony structures and soft tissues are unremarkable',
#  'there are xxxx xxxx pulmonary opacities with blunting of the bilateral costophrenic xxxx, on the right greater than left, with pleural thickening versus loculated pleural fluid along the peripheral aspect of the right upper lobe',
#  'the lungs focal airspace consolidation',
#  'mediastinum is shifted to the left as compared to the previous examination',
#  'stable right lower lung granuloma',
#  'no pneumothorax or pleural effusion present',
#  'there is a 13 mm nodule in the right lower lobe that is relatively dense, but not obviously calcified on the corresponding rib series',
#  'questionable thin-walled cavitary lesion in the right lower lobe, only seen on the ap view and may represent artifact',
#  'mildly tortuous aorta',
#  'mediastinal surgical clips are again noted',
#  'there mild degenerative changes throughout the thoracic spine',
#  'osseous structures are intact',
#  'pectus carinatum',
#  'mild rightward deviation of the trachea',
#  'xxxx opacity in the left upper lobe, xxxx atelectasis or scarring',
#  'central left midlung granuloma with calcified left hilar adenopathy',
#  'coronary artery stent',
#  'stable superior mediastinal contour with tortuous aorta',
#  'there is a stable calcified granuloma in the right lower lobe',
#  'there is a mild anterior wedge xxxx deformity of l1, age-indeterminate',
#  'osseous structures are within normal limits for patient age',
#  'deformity of the right clavicle related to remote xxxx is again seen',
#  'focal airspace consolidation is visualized in the superior segment of the left lower lobe, xxxx appreciated on lateral projection',
#  'scattered bilateral granulomas',
#  'visualized xxxx of the chest xxxx are within normal limits',
#  'there is evidence of previous anterior cervical spine fusion',
#  "these xxxx't contours are within normal limits",
#  'tortuous, ectatic thoracic aorta, unchanged',
#  'calcified granuloma in the anterior left lower lobe',
#  'small residual left apical pneumothorax has increased slightly in size the prior exam, now measuring approximately 0',
#  'ankle mortise intact',
#  'calcified granuloma is again seen in the right upper lobe',
#  'there is right basilar opacity',
#  'no focal consolidation or pleural effusions',
#  'probable old lateral right rib fractures',
#  'hyperinflated lungs with flattened diaphragm and increased retrosternal airspace',
#  'mild chronic degenerative changes are present within the thoracic spine',
#  'heart and mediastinum unremarkable',
#  'scattered bilateral calcified granulomas',
#  'lungs are clear without focal airspace disease',
#  'there are calcified hilar lymph xxxx suggesting prior granulomatous disease',
#  'xxxx opacities in the left lung base consistent with atelectasis',
#  'left lower lobe xxxx density xxxx representing atelectasis',
#  'xxxx left base density',
#  'the lungs are clear without focal infiltrate',
#  'heart size slightly enlarged',
#  'there are calcified subcarinal and right hilar lymph xxxx',
#  'there are mild chronic opacities in the left lung base with probable small residual effusion',
#  'atrial septal occluder artifact',
#  'there is prominence of the pulmonary arteries, right greater than left',
#  'lung volumes are low with central bronchovascular crowding and patchy basilar atelectasis',
#  'the remainder of the lungs are clear',
#  'the skeletal structures show senescent changes',
#  'left chest xxxx with associated central venous catheter tip overlying the cavoatrial junction',
#  'the pulmonary vasculaturity is increased',
#  'this is an apical lordotic view the chest',
#  'some blunting of the left costophrenic xxxx xxxx represent scarring or atelectasis',
#  'right inferior rib deformities',
#  'the mediastinum is unremarkable',
#  't-spine small osteophytes',
#  'stable calcified granuloma in the left lower lobe',
#  'bone demineralization',
#  'frontal and lateral views demonstrate the cardiomediastinal silhouette to be within normal limits',
#  'lungs are clear without focal consolidation, effusion or pneumothorax',
#  'multilevel degenerative disease of the spine',
#  'no visible pneumothorax or pleural effusion',
#  'there is calcified hilar lymph xxxx',
#  'no acute osseous findings',
#  'tracheostomy tube',
#  'right hilar calcifications xxxx sequela of prior granulomatous disease',
#  'stable elevation right hemidiaphragm compared to exam on xxxx',
#  'marrow pneumothorax, focal lung consolidation or pleural effusions',
#  'no large effusion, no visible pneumothorax within the limits of the study',
#  'there are calcified mediastinal lymph xxxx, with a calcified right lower lobe pulmonary nodule',
#  'xxxx onset right basal atelectasis with airspace disease and effusion suggestive of the chest infection',
#  'calcified granuloma in the left lung base',
#  'there has been interval development of a large right-sided pleural effusion',
#  'it is approximately 2 cm in diameter',
#  'displaced fracture of the mid one-third of the right clavicle',
#  'pa and lateral radiograph the chest demonstrate stable cardiomediastinal silhouette',
#  'xxxx b-lines seen at the lung bases',
#  'low lung volumes with magnified appearance of the heart, xxxx normal heart size',
#  'there are surgical clips, perhaps from cholecystectomy, in the right upper quadrant',
#  'there are no large pleural effusions',
#  'there is a moderate sized right pleural effusion',
#  'the lungs are clear bilaterally without focal area of consolidation, pleural effusion, or pneumothorax',
#  'xxxx airspace opacity at the superior segment of the right lower lobe',
#  'there is large right-sided pleural effusion and probable underlying associated compressive atelectasis',
#  'mild cardiomegaly, stable mediastinal contours',
#  'visualized osseous structures of the thorax demonstrates stable mild multilevel degenerative disc disease of the thoracolumbar spine as well as chronic left-sided rib fractures without acute abnormality',
#  'otherwise, no focal consolidation, large pleural effusion, or pneumothorax',
#  'lungs are hyperexpanded',
#  'large, flowing anterior endplate osteophytes of the thoracic spine',
#  'there basilar calcified granulomas',
#  'these appear to be located in the lingula',
#  'mild streaky scarring in the right upper lobe',
#  'the bony structures of the thorax are intact with no evidence of acute osseous abnormality',
#  'there are low lung volumes with xxxx opacities consistent with focal atelectasis',
#  'there is a healed left clavicle fracture',
#  'the lungs are hyperinflated with flattening of the diaphragms and tapering of the distal pulmonary vasculature',
#  'subsegmental atelectasis versus scarring in the right midlung and left lower lobe',
#  'clear lungs without pneumothorax or pleural effusion',
#  'chronic appearing left greater than right lung base scarring with possible small effusions',
#  'there are no soft tissue or bony abnormalities',
#  'persistent patchy retrocardiac airspace opacity xxxx atelectasis',
#  'hilar pulmonary venous vasculature stable compared to prior examination',
#  'normal hilar vasculature',
#  'the stomach contour normal',
#  'the visualized bony structures are intact',
#  'there is again mild elevation of the right hemidiaphragm',
#  'there is improved aeration in the lung bases with mild residual xxxx opacities compatible with scarring or atelectasis',
#  'levocurvature of the lumbar spine with significant degenerative change is also noted',
#  'there is a left chest xxxx with tip in the mid svc',
#  'ill-defined opacity is again noted in the region of the lingula',
#  'mortise radiographically stable',
#  'the aorta is atherosclerotic and ectatic',
#  'the heart is upper limits of normal in size',
#  'a large hiatal hernia is present',
#  'a strandy infiltrate has developed in the left lower lobe',
#  'stable cardiomediastinal silhouette with borderline cardiomegaly',
#  'pelvis',
#  'the thoracic aorta is mildly tortuous and calcified',
#  'minimal spondylosis of the lower thoracic spine',
#  '5 cm above the carina',
#  'thoracic aortic atherosclerotic calcifications are present',
#  'the cardiomediastinal silhouette is at the upper limits of normal in size but stable from prior exam',
#  'there may be a subtle airspace opacity in the right base near the midclavicular line',
#  'the thoracic aorta is calcified',
#  'negative for vascular congestion',
#  'persistent small right pleural effusion and xxxx xxxx atelectasis',
#  'frontal and lateral views',
#  'interstitial opacities greatest in the central lungs and bases',
#  'tortuous and dilated aorta',
#  'clear, hyperaerated lungs',
#  'interstitial markings are diffusely prominent throughout both lungs',
#  'the lung volumes are low, with bronchovascular crowding',
#  'there is a calcified lymph node in the right hilum',
#  'thoracic spine shows osteophyte formations at several levels',
#  'low lung volumes bilaterally, with lungs otherwise grossly clear',
#  'mild right basilar atelectasis and relative elevation of the right hemidiaphragm noted',
#  'no focal opacities',
#  'no focal consolidation is seen',
#  'external monitor leads xxxx the thorax',
#  'chronically increased interstitial markings without focal airspace consolidation, pleural effusion, pneumothorax',
#  'there is an ovoid opacity 3',
#  'left axillary surgical clips unchanged visualized xxxx of the chest xxxx are within normal limits',
#  'there is mild prominence of the right paratracheal soft tissues, stable in appearance from prior studies',
#  'the left lung is well-aerated without focal airspace consolidation, pleural effusions or pneumothorax',
#  'there is a vague opacity in the right infrahilar region',
#  'postsurgical changes include left chest pacemaker/icd with xxxx tips over the right atrium and right ventricle, sternotomy xxxx, and graft markers, and upper anterior mediastinal surgical clips',
#  'left basilar opacity xxxx represents chronic fibrosis/scar',
#  'sternotomy xxxx and surgical clips are again seen',
#  'heart size within normal limits, bronchovascular crowding without typical findings of pulmonary edema',
#  'small calcified left upper lung granuloma is noted',
#  'there is a xxxx opacity within the right lung base, xxxx representing atelectasis',
#  'there are no focal air space opacities',
#  'grossly clear lungs, without focal airspace consolidation, pleural effusion, or pneumothorax',
#  'there is no apparent pneumothorax',
#  'small centrally calcified granuloma within the lateral right lung base',
#  "they're multiple radiopaque densities overlying the patient",
#  'for example, there is a 12 mm left lower lobe nodule, xxxx seen on the frontal view',
#  'increase in xxxx opacities in the right lung base',
#  'pleural thickening along the inferior left lateral chest',
#  'in the interval, the interval, there has been development of multiple nodules in both the upper and lower lobes bilaterally',
#  'in the interval, consolidation has developed in the left upper lobe',
#  'possible subtle increased opacity in right apex versus technique',
#  'xxxx degenerative changes of the thoracic spine',
#  'two views of chest was obtained in ap projection',
#  'in the pleural spaces are clear',
#  'the lungs are hyperexpanded',
#  'there is mild tortuosity of the thoracic aorta',
#  'xxxx xxxx right and xxxx left pleural effusions',
#  'no large effusions or pneumothorax',
#  'sternotomy xxxx and mediastinal clips are unchanged',
#  'the cardiomediastinal silhouette is within normal limits of size and appearance',
#  'patchy left basal airspace opacity',
#  'right apical pleural retraction',
#  'limited degenerative change of the spine',
#  'xxxx xxxx right-sided chest tube tip now projects outside the thoracic cavity',
#  'there is right paratracheal density concerning for lymphadenopathy',
#  'stable appearance of the left upper lung lobe with scarring, volume loss, and pleural thickening',
#  'there is enlarged heart silhouette',
#  'stable mediastinal contours',
#  'there is increased kyphosis of the thoracic spine and there are multiple xxxx deformities',
#  "there is retrocardiac density which xxxx corresponds to patient's known hiatal hernia",
#  'a 9 mm pulmonary nodule is noted partially overlying the posterior 6th right rib on the frontal view',
#  'bilateral calcified hilar/perihilar lymph xxxx',
#  'there is continued interstitial prominence bilaterally',
#  'there is moderate cardiomegaly',
#  'no xxxx infiltrates',
#  'bilateral hilar fullness is present consistent with adenopathy',
#  'no interstitial edema or pleural effusion',
#  'there is atherosclerosis of the aortic xxxx',
#  'normal contour of the mediastinum and aorta',
#  'lungs mildly hyperinflated with flattened posterior diaphragm and increased retrosternal airspace',
#  'the cardiac silhouette pulmonary vascularity are normal',
#  'there is a small left pleural effusion',
#  'the heart is normal size with normal appearance the cardiomediastinal silhouette',
#  'nasogastric tube tip xxxx within the stomach body, stable',
#  'xxxx xxxx p',
#  'no focal consolidation is identified',
#  'no focal airspace disease, pleural effusion or pneumothorax',
#  't-spine osteophytes and dish',
#  'small left pleural effusion',
#  'acromioclavicular arthritis is present, xxxx severe',
#  'cardiac silhouette, pulmonary vascular pattern within normal limits',
#  'the xxxx are unremarkable',
#  'mild cardiomegaly is unchanged',
#  'low lung volumes bilaterally',
#  'no definite pleural effusions',
#  'this is a stable normal cardiomediastinal silhouette',
#  'no pulmonary nodules',
#  'xxxx airspace disease within the left lower lung',
#  'there is mild thoracic dextroscoliosis',
#  'allowing for technical factors the heart size is xxxx normal',
#  'after cirrhotic calcification of the thoracic aorta',
#  'there is no focal airspace disease, pneumothorax, or large pleural effusion',
#  'there is no large effusion or pneumothorax',
#  'central venous catheter is again noted',
#  'stable enlarged cardiac silhouette',
#  'normal pulmonary xxxx and interstitium',
#  'there is a xxxx like deformity of the anterior cortex of the xxxx body (lateral view)',
#  'clear lungs there are no large pleural effusions no evidence of displaced fractures',
#  ...]

# %% [markdown]
# # Identify Dataset for CLIP Model

# %%
imgs_analysis={}

imgs_findings_analysis_dict={}

unique_statements_set=set(unique_statements_lst)

num_pics_ctr=0

for i in img_findings_dict:
    findings_arr=i.split(".")
    for f in findings_arr:
        f=f.strip()
        f=" ".join(f.split())
        f=re.sub(r'[^\w\s]', '', f)
        
        if f in unique_statements_set:
            imgs_findings_analysis_dict[i]=img_findings_dict[i]
            num_pics_ctr+=len(img_findings_dict[i])
            continue

print("There are {} unique findings and {} images in the dataset to be considered for further analysis".format(len(imgs_findings_analysis_dict),num_pics_ctr))
# Out:
# There are 53 unique findings and 122 images in the dataset to be considered for further analysis

# %% [markdown]
# # CLIP

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

trgt_imgs_list=[imgs_findings_analysis_dict[i] for i in imgs_findings_analysis_dict]
trgt_imgs_list_flat=[i for lst in trgt_imgs_list for i in lst]
trgt_imgs_list_set=set(trgt_imgs_list_flat)
    
images=[]
for file in glob.glob('input/NLMCXR_png/*.png'):
    file_split_1=file.split(".")
    file_split_2=file_split_1[0].split("/")
    img_indx=file_split_2[2]
    
    if img_indx in trgt_imgs_list_set: 
        images.append(Image.open(file))

inputs = processor(text=unique_statements_lst,images=images,return_tensors="pt",padding=True)

outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3e84380240e7> in <module>
#      19
#      20 with torch.no_grad():
# ---> 21     image_features=model.encode_image(images)
#      22     text_features=model.encode_text(text)
#      23
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/clip/model.py in encode_image(self, image)
#     339
#     340     def encode_image(self, image):
# --> 341         return self.visual(image.type(self.dtype))
#     342
#     343     def encode_text(self, text):
#
# AttributeError: 'list' object has no attribute 'type'

# %% [markdown]
# # References
#
# - https://github.com/openai/CLIP
#
# - https://www.geeksforgeeks.org/part-speech-tagging-stop-words-using-nltk-python/
#
# - https://dida.do/blog/clip
